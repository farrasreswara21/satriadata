# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import openpyxl

# %%
df_metadata = pd.read_excel('Metadata.xlsx')
df_metadata.head(1)
# Out:
#   Variable Information Unnamed: 1 Unnamed: 2
# 0             Variable   Position      Label

# %%
new_header = df_metadata.iloc[0] #grab the first row for the header
df_metadata.columns = new_header #set the header row as the df header
df_metadata = df_metadata[1:] #take the data less the header row

# %%
df_metadata.head(26)
# Out:
# 0     Variable Position                                             Label
# 1       PSTV01        1                                     Nomor peserta
# 2       PSTV02        2                                    Nomor keluarga
# 3       PSTV15        3                                             Bobot
# 4        FKP02        4                                 ID Kunjungan FKTP
# 5        FKP03        5                     Tanggal datang kunjungan FKTP
# 6        FKP04        6                     Tanggal pulang kunjungan FKTP
# 7        FKP05        7                                     Provinsi FKTP
# 8        FKP06        8                               Kabupaten/Kota FKTP
# 9        FKP07        9                                  Kepemilikan FKTP
# 10       FKP08       10                                        Jenis FKTP
# 11       FKP09       11                                         Tipe FKTP
# 12       FKP10       12                            Tingkat Pelayanan FKTP
# ...

# %%
df = pd.read_csv('train_fktp.txt', header=None)
df.head()
# Out:
#             0          1           2                 3           4   \
# 0  157978748.0   50765420   20.064983         958073632  2019-08-01
# 1   95085112.0   26931775    2.626307  449590620P000054  2020-06-17
# 2  224470578.0  227368233    1.051830  467490619P000001  2019-06-01
# 3   63871289.0   62313678  364.741455  254321219Y002368  2019-12-21
# 4   29915626.0  113446188    1.050523   88681119P000020  2019-11-04
#
#            5   6     7   8   9   ...    16  \
# 0  2019-08-01  61  6108   3   1  ...  9999
# 1  2020-06-17  51  5171   9   3  ...  K297
# 2  2019-06-01  35  3516   9   2  ...  Z309
# 3  2019-12-21  34  3402   3   1  ...   I10
# 4  2019-11-04  35  3509   3   1  ...  I110
#
#                                                   17  18    19  20  21  22  \
# 0                                               9999  98  9998  98  98  98
# 1                             Gastritis, unspecified  98  9998  98  98  98
# ...

# %%
df.columns = df_metadata['Label'][:26]
df.head()
# Out:
# Label  Nomor peserta  Nomor keluarga       Bobot ID Kunjungan FKTP  \
# 0        157978748.0        50765420   20.064983         958073632
# 1         95085112.0        26931775    2.626307  449590620P000054
# 2        224470578.0       227368233    1.051830  467490619P000001
# 3         63871289.0        62313678  364.741455  254321219Y002368
# 4         29915626.0       113446188    1.050523   88681119P000020
#
# Label Tanggal datang kunjungan FKTP Tanggal pulang kunjungan FKTP  \
# 0                        2019-08-01                    2019-08-01
# 1                        2020-06-17                    2020-06-17
# 2                        2019-06-01                    2019-06-01
# 3                        2019-12-21                    2019-12-21
# 4                        2019-11-04                    2019-11-04
#
# Label  Provinsi FKTP  Kabupaten/Kota FKTP  Kepemilikan FKTP  Jenis FKTP  ...  \
# 0                 61                 6108                 3           1  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4056898 entries, 0 to 4056897
# Data columns (total 26 columns):
#  #   Column                                            Dtype
# ---  ------                                            -----
#  0   Nomor peserta                                     float64
#  1   Nomor keluarga                                    int64
#  2   Bobot                                             float64
#  3   ID Kunjungan FKTP                                 object
#  4   Tanggal datang kunjungan FKTP                     object
#  5   Tanggal pulang kunjungan FKTP                     object
#  6   Provinsi FKTP                                     int64
#  7   Kabupaten/Kota FKTP                               int64
#  8   Kepemilikan FKTP                                  int64
#  9   Jenis FKTP                                        int64
#  10  Tipe FKTP                                         int64
# ...

# %%
df.shape
# Out:
# (4056898, 26)

# %%
df.isnull().sum()
# Out:
# Label
# Nomor peserta                                             0
# Nomor keluarga                                            0
# Bobot                                                     0
# ID Kunjungan FKTP                                         0
# Tanggal datang kunjungan FKTP                             0
# Tanggal pulang kunjungan FKTP                             0
# Provinsi FKTP                                             0
# Kabupaten/Kota FKTP                                       0
# Kepemilikan FKTP                                          0
# Jenis FKTP                                                0
# Tipe FKTP                                                 0
# Tingkat Pelayanan FKTP                                    0
# Jenis Poli FKTP                                           1
# Segmen Peserta saat akses layanan FKTP                    0
# Kode dan nama diagnosis ICD 10 (3 digit)                  0
# Kode diagnosis ICD 10 (3 digit)                     1380241
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Kelas Status Pulang Peserta'].value_counts()
# Out:
# Belum_Sehat    2634511
# Sehat          1422387
# Name: Kelas Status Pulang Peserta, dtype: int64
